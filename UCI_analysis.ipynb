# %% [markdown]
# # Estimation of Obesity Levels Based On Eating Habits and Physical Conditions
# Key Features: gender, age, height, weight, eating habits, physical conditon, lifestyle habits \
# Source: https://archive.ics.uci.edu/dataset/544/estimation+of+obesity+levels+based+on+eating+habits+and+physical+condition \
# The estimation of obesity levels in people from the countries of Mexico, Peru and Colombia, with ages between 14 and 61 \
#
# Hypothesis: Dietary factors like not tracking calories and snacking in between meals are most heavily correlated with obesity.

# %%
### Verify all libraries are installed in your machine first. 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 

# Other libraries that may be useful in the future. 
# import duckdb # for using sql syntax to access a df 
# import pandasql # also for using sql to access df - have slightly different features /advantages"
# import pil # python imaging library for opening, manipulating and saving images

## Functions that may be useful. 
## %%sql

# %%
df = pd.read_csv("DataSets/UCI_ObesityDataSet.csv")
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
# Rename labels for easy readability and intuitive data access. 
df = df.rename(columns = {'Gender':'gender', 'Age':'age', 'Height':'height', 'Weight':'weight','FAVC':'eat_high_calorie_frequently', 
                          'FCVC':'eat_vegetables_usually', 'NCP':'daily_meal_count', 'CAEC':'snack_between_meals', 'SMOKE':'smoke', 
                          'CH2O':'daily_water_intake', 'SCC':'monitor_calories', 'FAF':'activity_frequency', 'TUE':'time_on_technology', 
                          'CALC':'alcohol_frequency','MTRANS':'transportation', 'NObeyesdad':'obesity_level'})
df.head()
# Out:
#    gender   age  height  weight family_history_with_overweight  \
# 0  Female  21.0    1.62    64.0                            yes
# 1  Female  21.0    1.52    56.0                            yes
# 2    Male  23.0    1.80    77.0                            yes
# 3    Male  27.0    1.80    87.0                             no
# 4    Male  22.0    1.78    89.8                             no
#
#   eat_high_calorie_frequently  eat_vegetables_usually  daily_meal_count  \
# 0                          no                     2.0               3.0
# 1                          no                     3.0               3.0
# 2                          no                     2.0               3.0
# 3                          no                     3.0               3.0
# 4                          no                     2.0               1.0
#
#   snack_between_meals smoke  daily_water_intake monitor_calories  \
# 0           Sometimes    no                 2.0               no
# 1           Sometimes   yes                 3.0              yes
# 2           Sometimes    no                 2.0               no
# 3           Sometimes    no                 2.0               no
# 4           Sometimes    no                 2.0               no
#
#    activity_frequency  time_on_technology alcohol_frequency  \
# 0                 0.0                 1.0                no
# 1                 3.0                 0.0         Sometimes
# 2                 2.0                 1.0        Frequently
# 3                 2.0                 0.0        Frequently
# 4                 0.0                 0.0         Sometimes
#
#           transportation        obesity_level
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
cell_count = df.size
row_count = df.shape[0]
column_count = df.shape[1]

print(cell_count)
print(row_count)
print(column_count)
# Out:
# 35887
# 2111
# 17

# %%
df.describe()
# Out:
#                age       height       weight  eat_vegetables_usually  \
# count  2111.000000  2111.000000  2111.000000             2111.000000
# mean     24.312600     1.701677    86.586058                2.419043
# std       6.345968     0.093305    26.191172                0.533927
# min      14.000000     1.450000    39.000000                1.000000
# 25%      19.947192     1.630000    65.473343                2.000000
# 50%      22.777890     1.700499    83.000000                2.385502
# 75%      26.000000     1.768464   107.430682                3.000000
# max      61.000000     1.980000   173.000000                3.000000
#
#        daily_meal_count  daily_water_intake  activity_frequency  \
# count       2111.000000         2111.000000         2111.000000
# mean           2.685628            2.008011            1.010298
# std            0.778039            0.612953            0.850592
# min            1.000000            1.000000            0.000000
# 25%            2.658738            1.584812            0.124505
# 50%            3.000000            2.000000            1.000000
# 75%            3.000000            2.477420            1.666678
# max            4.000000            3.000000            3.000000
#
#        time_on_technology          bmi
# count         2111.000000  2111.000000
# mean             0.657866    29.700159
# std              0.608927     8.011337
# min              0.000000    12.998685
# 25%              0.000000    24.325802
# 50%              0.625350    28.719089
# 75%              1.000000    36.016501
# max              2.000000    50.811753

# %%
print(df['obesity_level'].unique()) # not that there is no underweight category despite bmi<18 being considered underweight

# add bmi feature 
df['bmi'] = df['weight']/(df['height']**2)

# add obese binary feature
df['obese'] = (df['bmi'] >= 25).astype(int)
df.head(20)
# Out:
# ['Normal_Weight' 'Overweight_Level_I' 'Overweight_Level_II'
#  'Obesity_Type_I' 'Insufficient_Weight' 'Obesity_Type_II'
#  'Obesity_Type_III']
#     gender   age  height  weight family_history_with_overweight  \
# 0   Female  21.0    1.62    64.0                            yes
# 1   Female  21.0    1.52    56.0                            yes
# 2     Male  23.0    1.80    77.0                            yes
# 3     Male  27.0    1.80    87.0                             no
# 4     Male  22.0    1.78    89.8                             no
# 5     Male  29.0    1.62    53.0                             no
# 6   Female  23.0    1.50    55.0                            yes
# 7     Male  22.0    1.64    53.0                             no
# 8     Male  24.0    1.78    64.0                            yes
# 9     Male  22.0    1.72    68.0                            yes
# 10    Male  26.0    1.85   105.0                            yes
# 11  Female  21.0    1.72    80.0                            yes
# 12    Male  22.0    1.65    56.0                             no
# 13    Male  41.0    1.80    99.0                             no
# 14    Male  23.0    1.77    60.0                            yes
# 15  Female  22.0    1.70    66.0                            yes
# 16    Male  27.0    1.93   102.0                            yes
# 17  Female  29.0    1.53    78.0                             no
# 18  Female  30.0    1.71    82.0                            yes
# 19  Female  23.0    1.65    70.0                            yes
#
#    eat_high_calorie_frequently  eat_vegetables_usually  daily_meal_count  \
# 0                           no                     2.0               3.0
# 1                           no                     3.0               3.0
# 2                           no                     2.0               3.0
# 3                           no                     3.0               3.0
# 4                           no                     2.0               1.0
# 5                          yes                     2.0               3.0
# 6                          yes                     3.0               3.0
# 7                           no                     2.0               3.0
# 8                          yes                     3.0               3.0
# 9                          yes                     2.0               3.0
# 10                         yes                     3.0               3.0
# 11                         yes                     2.0               3.0
# 12                          no                     3.0               3.0
# 13                         yes                     2.0               3.0
# 14                         yes                     3.0               1.0
# 15                          no                     3.0               3.0
# 16                         yes                     2.0               1.0
# 17                         yes                     2.0               1.0
# 18                         yes                     3.0               4.0
# 19                          no                     2.0               1.0
#
#    snack_between_meals smoke  daily_water_intake monitor_calories  \
# 0            Sometimes    no                 2.0               no
# 1            Sometimes   yes                 3.0              yes
# 2            Sometimes    no                 2.0               no
# 3            Sometimes    no                 2.0               no
# 4            Sometimes    no                 2.0               no
# 5            Sometimes    no                 2.0               no
# 6            Sometimes    no                 2.0               no
# 7            Sometimes    no                 2.0               no
# 8            Sometimes    no                 2.0               no
# 9            Sometimes    no                 2.0               no
# 10          Frequently    no                 3.0               no
# 11          Frequently    no                 2.0              yes
# 12           Sometimes    no                 3.0               no
# 13           Sometimes    no                 2.0               no
# 14           Sometimes    no                 1.0               no
# 15              Always    no                 2.0              yes
# 16           Sometimes    no                 1.0               no
# 17           Sometimes    no                 2.0               no
# 18          Frequently   yes                 1.0               no
# 19           Sometimes    no                 2.0               no
#
#     activity_frequency  time_on_technology alcohol_frequency  \
# 0                  0.0                 1.0                no
# 1                  3.0                 0.0         Sometimes
# 2                  2.0                 1.0        Frequently
# 3                  2.0                 0.0        Frequently
# 4                  0.0                 0.0         Sometimes
# 5                  0.0                 0.0         Sometimes
# 6                  1.0                 0.0         Sometimes
# 7                  3.0                 0.0         Sometimes
# 8                  1.0                 1.0        Frequently
# 9                  1.0                 1.0                no
# 10                 2.0                 2.0         Sometimes
# 11                 2.0                 1.0         Sometimes
# 12                 2.0                 0.0         Sometimes
# 13                 2.0                 1.0        Frequently
# 14                 1.0                 1.0         Sometimes
# 15                 2.0                 1.0         Sometimes
# 16                 1.0                 0.0         Sometimes
# 17                 0.0                 0.0                no
# 18                 0.0                 0.0                no
# 19                 0.0                 0.0         Sometimes
#
#            transportation        obesity_level        bmi  obese
# 0   Public_Transportation        Normal_Weight  24.386526      0
# 1   Public_Transportation        Normal_Weight  24.238227      0
# 2   Public_Transportation        Normal_Weight  23.765432      0
# 3                 Walking   Overweight_Level_I  26.851852      1
# 4   Public_Transportation  Overweight_Level_II  28.342381      1
# 5              Automobile        Normal_Weight  20.195092      0
# 6               Motorbike        Normal_Weight  24.444444      0
# 7   Public_Transportation        Normal_Weight  19.705532      0
# 8   Public_Transportation        Normal_Weight  20.199470      0
# 9   Public_Transportation        Normal_Weight  22.985398      0
# 10  Public_Transportation       Obesity_Type_I  30.679328      1
# 11  Public_Transportation  Overweight_Level_II  27.041644      1
# 12  Public_Transportation        Normal_Weight  20.569330      0
# 13             Automobile       Obesity_Type_I  30.555556      1
# 14  Public_Transportation        Normal_Weight  19.151585      0
# 15  Public_Transportation        Normal_Weight  22.837370      0
# 16  Public_Transportation  Overweight_Level_II  27.383285      1
# 17             Automobile       Obesity_Type_I  33.320518      1
# 18             Automobile  Overweight_Level_II  28.042817      1
# 19  Public_Transportation   Overweight_Level_I  25.711662      1

# %%
df.describe()
# Out:
#                age       height       weight  eat_vegetables_usually  \
# count  2111.000000  2111.000000  2111.000000             2111.000000
# mean     24.312600     1.701677    86.586058                2.419043
# std       6.345968     0.093305    26.191172                0.533927
# min      14.000000     1.450000    39.000000                1.000000
# 25%      19.947192     1.630000    65.473343                2.000000
# 50%      22.777890     1.700499    83.000000                2.385502
# 75%      26.000000     1.768464   107.430682                3.000000
# max      61.000000     1.980000   173.000000                3.000000
#
#        daily_meal_count  daily_water_intake  activity_frequency  \
# count       2111.000000         2111.000000         2111.000000
# mean           2.685628            2.008011            1.010298
# std            0.778039            0.612953            0.850592
# min            1.000000            1.000000            0.000000
# 25%            2.658738            1.584812            0.124505
# 50%            3.000000            2.000000            1.000000
# 75%            3.000000            2.477420            1.666678
# max            4.000000            3.000000            3.000000
#
#        time_on_technology          bmi        obese
# count         2111.000000  2111.000000  2111.000000
# mean             0.657866    29.700159     0.729512
# std              0.608927     8.011337     0.444317
# min              0.000000    12.998685     0.000000
# 25%              0.000000    24.325802     0.000000
# 50%              0.625350    28.719089     1.000000
# 75%              1.000000    36.016501     1.000000
# max              2.000000    50.811753     1.000000

# %% [markdown]
# # Relative Risk
# * Calculate RR of being obese if female vs male
# * RR of of being obese if counting calories vs not
# * RR of being obese if drinking alcohol vs not
# * RR of walking vs not
# * RR of eating vegetables vs not
# * RR active vs not

# %% [markdown]
# # Chi-Squared Tests
# * Independence - can check independence for: (gender, obesity), (water, obesity), (water, meal_count), (alcohol, obesity), (age, obesity)
# * Goodness of fit ? probably not
# * Homogeneity ? probably not

# %% [markdown]
# # Make Correlation Table to find residuals

# %% [markdown]
# # Correlation Heat Map
